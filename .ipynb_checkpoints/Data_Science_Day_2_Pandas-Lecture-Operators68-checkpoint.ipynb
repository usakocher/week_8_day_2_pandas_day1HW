# %% [markdown]
# # Pandas

# %% [markdown]
# ## Tasks Today:
#
# 0) <b>Pre-Work</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Numpy Random Sampling
#
# 1) <b>Pandas</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; a) Importing <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; b) Tabular Data Structures <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - from_dict() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - read_csv() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; c) <b>In-Class Exercise #1</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; d) Accessing Data <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Indexing <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - df.loc <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - keys() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Slicing a DataFrame <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; e) Built-In Methods <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - head() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - tail() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - shape <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - describe() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - sort_values() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - .columns <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; f) <b>In-Class Exercise #2</b> <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; g) Filtration <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Conditionals <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Subsetting <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; h) Column Transformations <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Generating a New Column w/Data <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - User Defined Function <br>
#  &nbsp;&nbsp;&nbsp;&nbsp; i) Aggregations <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - groupby() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - Type of groupby() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - mean() <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - groupby() w/Multiple Columns <br>
#  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; - drop_duplicates() <br>

# %% [markdown]
# ## Numpy Random Sampling

# %%
import numpy as np

# A single call generates a single random number
print('Here is a random number: %s' % np.random.uniform())
print(f'Here is a random number: {np.random.uniform()}')

# You can also pass some bounds
print('Here is a random number between 0 and 1 Million: %s' % np.random.uniform(0, 1e6))

# You can also generate a bunch of random numbers all at once
print('Here are 3 random numbers between 0 and 1 Million: %s' % np.random.uniform(0, 1e6, 3))

# Even matrices and tensors with weird shapes
print('Here is a 3x3 matrix of random numbers between 0 and 1 Million: \n %s' % np.random.uniform(0, 1e6, (3, 3)))

# instead of float values, generating random integers
print('Using Random Integer: %s' % np.random.randint(0, 10, 4))
# Out:
# Here is a random number: 0.4631537842141975
# Here is a random number: 0.2809582323169132
# Here is a random number between 0 and 1 Million: 59716.64451503455
# Here are 3 random numbers between 0 and 1 Million: [191678.85704992 227642.90526457 722271.55358814]
# Here is a 3x3 matrix of random numbers between 0 and 1 Million:
#  [[289965.94367446 648408.49187209 103818.07512384]
#  [756450.55285905 186686.2365036  219757.19666053]
#  [738393.71971453 131001.49912825 621758.96962745]]
# Using Random Integer: [6 5 6 2]

# %% [markdown]
# ## Pandas <br>
#
# <p>Pandas is a flexible data analysis library built on top of NumPy that is excellent for working with tabular data. It is currently the de-facto standard for Python-based data analysis, and fluency in Pandas will do wonders for your productivity and frankly your resume. It is one of the fastest ways of getting from zero to answer in existence. </p>
#
# <ul>
#     <li>Pandas is a Python module, written in C. The Pandas module is a high performance, highly efficient, and high level data analysis library. It allows us to work with large sets of data called dataframes.</li>
#     <li>Series is a one-dimensional labeled array capable of holding data of any type (integer, string, float, python objects, etc.)</li>
#     <li>Dataframe = Spreadsheet (has column headers, index, etc.)</li>
# </ul>

# %% [markdown]
# ### Importing

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (1.2.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.16.5 in c:\programdata\anaconda3\lib\site-packages (from pandas) (1.20.1)
# Requirement already satisfied: pytz>=2017.3 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
import pandas as pd

# always use pd, standard for data science

# %% [markdown]
# ### Tabular data structures <br>
# <p>The central object of study in Pandas is the DataFrame, which is a tabular data structure with rows and columns like an excel spreadsheet. The first point of discussion is the creation of dataframes both from native Python dictionaries, and text files through the Pandas I/O system.</p>

# %%
names = ['Alice',
         'Bob',
         'James',
         'Beth', 
         'John', 
         'Sally',
         'Richard', 
         'Lauren',
         'Brandon', 
         'Sabrina']

ages = np.random.randint(18,35,len(names))

my_people = {
    'names': names,
    'ages': ages
}

my_people
# Out:
# {'names': ['Alice',
#   'Bob',
#   'James',
#   'Beth',
#   'John',
#   'Sally',
#   'Richard',
#   'Lauren',
#   'Brandon',
#   'Sabrina'],
#  'ages': array([21, 20, 31, 19, 22, 32, 21, 33, 34, 26])}

# %% [markdown]
# ##### from_dict()
#
# <p>Let's convert our not-so-useful-for-analysis dict into a Pandas dataframe. We can use the from_dict function to do this easily using Pandas:</p>

# %%
data = pd.DataFrame.from_dict(my_people)

data
# Out:
#      names  ages
# 0    Alice    21
# 1      Bob    20
# 2    James    31
# 3     Beth    19
# 4     John    22
# 5    Sally    32
# 6  Richard    21
# 7   Lauren    33
# 8  Brandon    34
# 9  Sabrina    26

# %% [markdown]
# ##### read_csv()

# %%
pd.set_option('display.max_columns', 25)
pd.set_option('display.max_rows', 100)

marathon_data = pd.read_csv('../files/boston_marathon2017_edited.csv', sep=",")
marathon_data
# Out:
#                           10K                     15K                    20K  \
# 0      12/30/1899 12:30:28 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:15 AM
# 1      12/30/1899 12:30:27 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:15 AM
# 2      12/30/1899 12:30:29 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:16 AM
# 3      12/30/1899 12:30:29 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:19 AM
# 4      12/30/1899 12:30:28 AM  12/30/1899 12:45:44 AM  12/30/1899 1:01:15 AM
# ...                       ...                     ...                    ...
# 26405   12/30/1899 1:35:41 AM   12/30/1899 2:23:35 AM  12/30/1899 3:12:44 AM
# 26406   12/30/1899 1:05:33 AM   12/30/1899 1:52:17 AM  12/30/1899 2:49:41 AM
# 26407   12/30/1899 1:43:36 AM   12/30/1899 2:32:36 AM                    NaN
# 26408   12/30/1899 1:27:19 AM   12/30/1899 2:17:17 AM  12/30/1899 3:11:40 AM
# 26409   12/30/1899 1:17:12 AM   12/30/1899 2:00:10 AM  12/30/1899 2:58:55 AM
#
#                          25K                    30K                    35K  \
# 0      12/30/1899 1:16:59 AM  12/30/1899 1:33:01 AM  12/30/1899 1:48:19 AM
# 1      12/30/1899 1:16:59 AM  12/30/1899 1:33:01 AM  12/30/1899 1:48:19 AM
# 2      12/30/1899 1:17:00 AM  12/30/1899 1:33:01 AM  12/30/1899 1:48:31 AM
# 3      12/30/1899 1:17:00 AM  12/30/1899 1:33:01 AM  12/30/1899 1:48:58 AM
# 4      12/30/1899 1:16:59 AM  12/30/1899 1:33:01 AM  12/30/1899 1:48:41 AM
# ...                      ...                    ...                    ...
# 26405  12/30/1899 4:12:06 AM  12/30/1899 5:03:08 AM  12/30/1899 5:55:18 AM
# 26406  12/30/1899 3:50:19 AM  12/30/1899 4:50:01 AM  12/30/1899 5:53:48 AM
# 26407  12/30/1899 4:15:21 AM  12/30/1899 5:06:37 AM  12/30/1899 6:00:33 AM
# 26408  12/30/1899 4:06:10 AM  12/30/1899 5:07:09 AM  12/30/1899 6:06:07 AM
# 26409  12/30/1899 4:27:14 AM  12/30/1899 5:37:13 AM  12/30/1899 6:39:07 AM
#
#                          40K                      5K  Age      Bib  \
# 0      12/30/1899 2:02:53 AM  12/30/1899 12:15:25 AM   24     11.0
# 1      12/30/1899 2:03:14 AM  12/30/1899 12:15:24 AM   30     17.0
# 2      12/30/1899 2:03:38 AM  12/30/1899 12:15:25 AM   25     23.0
# 3      12/30/1899 2:04:35 AM  12/30/1899 12:15:25 AM   32     21.0
# 4      12/30/1899 2:05:00 AM  12/30/1899 12:15:25 AM   31      9.0
# ...                      ...                     ...  ...      ...
# 26405  12/30/1899 6:46:57 AM  12/30/1899 12:46:44 AM   61  25166.0
# 26406  12/30/1899 6:54:21 AM  12/30/1899 12:32:03 AM   25  25178.0
# 26407  12/30/1899 6:54:38 AM  12/30/1899 12:53:11 AM   57  27086.0
# 26408  12/30/1899 6:56:08 AM  12/30/1899 12:40:34 AM   64  25268.0
# 26409  12/30/1899 7:41:23 AM  12/30/1899 12:39:36 AM   48  25266.0
#
#        Overall Time in Seconds Citizenship  ...           City  Country  \
# 0                         7777         KEN  ...       Keringet      KEN
# 1                         7798         USA  ...       Portland      USA
# 2                         7828         JPN  ...   Machida-City      JPN
# 3                         7928         USA  ...  Mammoth Lakes      USA
# 4                         7955         KEN  ...       Marakwet      KEN
# ...                        ...         ...  ...            ...      ...
# 26405                    25779         USA  ...        Ontario      USA
# 26406                    26219         USA  ...   Fayetteville      USA
# 26407                    26377         USA  ...        Malvern      USA
# 26408                    26444         USA  ...       New York      USA
# 26409                    28694         USA  ...     Alpharetta      USA
#
#       Division Gender                   Half  M/F                      Name  \
# 0            1      1  12/30/1899 1:04:35 AM    M           Kirui, Geoffrey
# 1            2      2  12/30/1899 1:04:35 AM    M               Rupp, Galen
# 2            3      3  12/30/1899 1:04:36 AM    M             Osako, Suguru
# 3            4      4  12/30/1899 1:04:45 AM    M          Biwott, Shadrack
# 4            5      5  12/30/1899 1:04:35 AM    M            Chebet, Wilson
# ...        ...    ...                    ...  ...                       ...
# 26405      344  11972  12/30/1899 3:23:31 AM    F  Steinbach, Paula Eyvonne
# 26406     4774  14436  12/30/1899 3:00:26 AM    M        Avelino, Andrew R.
# 26407      698  11973  12/30/1899 3:36:24 AM    F           Hantel, Johanna
# 26408     1043  14437  12/30/1899 3:22:30 AM    M              Reilly, Bill
# 26409     2553  14438  12/30/1899 3:08:16 AM    M             Rigsby, Scott
#
#       Number of Records          Official Time  Overall  \
# 0                     1  12/30/1899 2:09:37 AM        1
# 1                     1  12/30/1899 2:09:58 AM        2
# 2                     1  12/30/1899 2:10:28 AM        3
# 3                     1  12/30/1899 2:12:08 AM        4
# 4                     1  12/30/1899 2:12:35 AM        5
# ...                 ...                    ...      ...
# 26405                 1  12/30/1899 7:09:39 AM    26407
# 26406                 1  12/30/1899 7:16:59 AM    26408
# 26407                 1  12/30/1899 7:19:37 AM    26409
# 26408                 1  12/30/1899 7:20:44 AM    26410
# 26409                 1  12/30/1899 7:58:14 AM    26411
#
#                          Pace  State
# 0      12/30/1899 12:04:57 AM    NaN
# 1      12/30/1899 12:04:58 AM     OR
# 2      12/30/1899 12:04:59 AM    NaN
# 3      12/30/1899 12:05:03 AM     CA
# 4      12/30/1899 12:05:04 AM    NaN
# ...                       ...    ...
# 26405  12/30/1899 12:16:24 AM     CA
# 26406  12/30/1899 12:16:40 AM     NC
# 26407  12/30/1899 12:16:47 AM     PA
# 26408  12/30/1899 12:16:49 AM     NY
# 26409  12/30/1899 12:18:15 AM     GA
#
# [26410 rows x 26 columns]

# %% [markdown]
# ### In-Class Exercise #1 - Read in Boston Red Sox Hitting Data <br>
# <p>Use the pandas read_csv() method to read in the statistics from the two files yesterday.</p>

# %%
# sep is defaulted to comma

bs2017 = pd.read_csv('../files/redsox_2017_hitting.txt')
bs2018 = pd.read_csv('../files/redsox_2018_hitting.txt')

bs2018
# Out:
#     Rk Pos                Name  Age    G   PA   AB    R    H  2B  3B  HR  ...  \
# 0    1   C          Sandy Leon   29   89  288  265   30   47  12   0   5  ...
# 1    2  1B      Mitch Moreland   32  124  459  404   57   99  23   4  15  ...
# 2    3  2B       Eduardo Nunez   31  127  502  480   56  127  23   3  10  ...
# 3    4  SS     Xander Bogaerts   25  136  580  513   72  148  45   3  23  ...
# 4    5  3B       Rafael Devers   21  121  490  450   59  108  24   0  21  ...
# 5    6  LF   Andrew Benintendi   23  148  661  579  103  168  41   6  16  ...
# 6    7  CF  Jackie Bradley Jr.   28  144  535  474   76  111  33   4  13  ...
# 7    8  RF        Mookie Betts   25  136  614  520  129  180  47   5  32  ...
# 8    9  DH       J.D. Martinez   30  150  649  569  111  188  37   2  43  ...
# 9   10  MI          Brock Holt   30  109  367  321   41   89  18   2   7  ...
# 10  11   C   Christian Vazquez   27   80  269  251   24   52  10   0   3  ...
# 11  12  UT       Blake Swihart   26   82  207  192   28   44  10   0   3  ...
# 12  13  UT      Hanley Ramirez   34   44  195  177   25   45   7   0   6  ...
# 13  14  1B        Steve Pearce   35   50  165  136   19   38   8   1   7  ...
# 14  15  2B         Ian Kinsler   36   37  143  132   17   32   6   0   1  ...
# 15  16  SS         Tzu-Wei Lin   24   37   73   65   15   16   6   1   1  ...
# 16  17  UT          Sam Travis   24   19   38   36    5    8   3   0   1  ...
# 17  18  UT    Brandon Phillips   37    9   27   23    4    3   0   0   1  ...
# 18  19  2B      Dustin Pedroia   34    3   13   11    1    1   0   0   0  ...
# 19  20   C          Dan Butler   31    2    7    6    0    1   0   0   0  ...
#
#      SO     BA    OBP    SLG    OPS  OPS+   TB  GDP  HBP  SH  SF  IBB
# 0    75  0.177  0.232  0.279  0.511    37   74    6    4   3   1    0
# 1   102  0.245  0.325  0.433  0.758   102  175   12    0   0   5    2
# 2    69  0.265  0.289  0.388  0.677    81  186   17    2   1   3    0
# 3   102  0.288  0.360  0.522  0.883   135  268   14    6   0   6    4
# 4   121  0.240  0.298  0.433  0.731    94  195    9    0   0   2    6
# 5   106  0.290  0.366  0.465  0.830   123  269    9    2   2   7    1
# 6   137  0.234  0.314  0.403  0.717    92  191    6   11   0   4    3
# 7    91  0.346  0.438  0.640  1.078   186  333    5    8   0   5    8
# 8   146  0.330  0.402  0.629  1.031   173  358   19    4   0   7   11
# 9    73  0.277  0.362  0.411  0.774   109  132    7    7   0   2    2
# 10   41  0.207  0.257  0.283  0.540    46   71    5    4   1   0    1
# 11   57  0.229  0.285  0.328  0.613    65   63    4    0   0   0    0
# 12   35  0.254  0.313  0.395  0.708    90   70    9    2   0   2    0
# 13   27  0.279  0.394  0.507  0.901   141   69    1    5   0   2    0
# 14   24  0.242  0.294  0.311  0.604    64   41    5    0   0   1    0
# 15   17  0.246  0.329  0.415  0.744   100   27    0    0   0   0    0
# 16   10  0.222  0.263  0.389  0.652    73   14    1    0   0   0    0
# 17    7  0.130  0.259  0.261  0.520    42    6    1    0   0   0    0
# 18    1  0.091  0.231  0.091  0.322    -7    1    0    0   0   0    0
# 19    2  0.167  0.143  0.167  0.310   -17    1    0    0   0   1    0
#
# [20 rows x 28 columns]

# %% [markdown]
# ### Accessing Data <br>

# %% [markdown]
# ##### Indexing
#
# <p>You can directly select a column of a dataframe just like you would a dict. The result is a Pandas 'Series' object.</p>

# %%
data_ages = data['ages']

print(data_ages)


# print out the type of the variable data
# Series
print(type(data_ages))
# DataFrame
print(type(data))

# DataSeries Index - starting at 0 
print(data_ages[3])

# key first, row index second
print(data['ages'][3])

# print(float(data_ages[0]))
# print(data_ages)
# Out:
# 0    21
# 1    20
# 2    31
# 3    19
# 4    22
# 5    32
# 6    21
# 7    33
# 8    34
# 9    26
# Name: ages, dtype: int32
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>
# 19
# 19

# %% [markdown]
# ##### df.loc

# %% [markdown]
# <p>Along the horizontal dimension, rows of Pandas DataFrames are Row objects. You will notice there is a third column present in the DataFrame - this is the $\textit{index}$. It is automatically generated as a row number, but can be reassigned to a column of your choice using the DataFrame.set_index(colname) method. We can use it to access particular Pandas $\textit{rows}$, which are also Series objects:</p>

# %%
print(data)
# Grab the first row of data -- by the index of the row
first_row = data.loc[0]
print('\n',first_row)
# Getting Multiple values from a df.loc
multiple_rows = data.loc[ [0,1,2] ]
print('\n',multiple_rows)
print('\n',type(multiple_rows))
# Using df.loc and producing a Dataframe at the end
multiple_people_df = data.loc[range(3)][['names', 'ages']]
print('\n',multiple_people_df)

# Reset our my_people dataframe index
reset_index = data.loc[[0,1,2,3]].set_index('names')
print('\n',reset_index)
print('\n',reset_index.loc['Alice'])

# reset_index.reset_index()
new_index = reset_index.reset_index()
new_index

# print(reset_index.loc['James'])
# print(data.loc[2])
# Out:
#      names  ages
# 0    Alice    21
# 1      Bob    20
# 2    James    31
# 3     Beth    19
# 4     John    22
# 5    Sally    32
# 6  Richard    21
# 7   Lauren    33
# 8  Brandon    34
# 9  Sabrina    26
#
#  names    Alice
# ages        21
# Name: 0, dtype: object
#
#     names  ages
# 0  Alice    21
# 1    Bob    20
# 2  James    31
#
#  <class 'pandas.core.frame.DataFrame'>
#
#     names  ages
# 0  Alice    21
# 1    Bob    20
# 2  James    31
#
#         ages
# names
# Alice    21
# Bob      20
# James    31
# Beth     19
#
#  ages    21
# Name: Alice, dtype: int32
#    names  ages
# 0  Alice    21
# 1    Bob    20
# 2  James    31
# 3   Beth    19

# %% [markdown]
# ##### keys()

# %%
# Access all of the keys/columns of the dataframe
# Dataframe.keys()

print(data.keys())
print(type(bs2017.keys()))
print(type(bs2017.keys().tolist()))
# Out:
# Index(['names', 'ages'], dtype='object')
# <class 'pandas.core.indexes.base.Index'>
# <class 'list'>

# %% [markdown]
# ##### Slicing a DataFrame

# %%
# printing all data for context
bs2017[2:5]
# Out:
#    Rk Pos             Name  Age    G   PA   AB   R    H  2B  3B  HR  ...   SO  \
# 2   3  2B   Dustin Pedroia   33  105  463  406  46  119  19   0   7  ...   48
# 3   4  SS  Xander Bogaerts   24  148  635  571  94  156  32   6  10  ...  116
# 4   5  3B    Rafael Devers   20   58  240  222  34   63  14   0  10  ...   57
#
#       BA    OBP    SLG    OPS  OPS+   TB  GDP  HBP  SH  SF  IBB
# 2  0.293  0.369  0.392  0.760   100  159   11    2   2   4    4
# 3  0.273  0.343  0.403  0.746    95  230   17    6   0   2    6
# 4  0.284  0.338  0.482  0.819   111  107    5    0   0   0    3
#
# [3 rows x 28 columns]

# %% [markdown]
# ### Built-In Methods <br>
#
# <p>These are methods that are frequently used when using Pandas to make your life easier. It is possible to spend a whole week simply exploring the built-in functions supported by DataFrames in Pandas. Here however, we will simply highlight a few ones that might be useful, to give you an idea of what's possible out of the box with Pandas:</p>

# %% [markdown]
# ##### head()

# %%
# DataFrame.head()  -- Accepts integer parameter(gives access to more rows)
# default to 5
bs2017.head()
# Out:
#    Rk Pos               Name  Age    G   PA   AB   R    H  2B  3B  HR  ...  \
# 0   1   C  Christian Vazquez   26   99  345  324  43   94  18   2   5  ...
# 1   2  1B     Mitch Moreland   31  149  576  508  73  125  34   0  22  ...
# 2   3  2B     Dustin Pedroia   33  105  463  406  46  119  19   0   7  ...
# 3   4  SS    Xander Bogaerts   24  148  635  571  94  156  32   6  10  ...
# 4   5  3B      Rafael Devers   20   58  240  222  34   63  14   0  10  ...
#
#     SO     BA    OBP    SLG    OPS  OPS+   TB  GDP  HBP  SH  SF  IBB
# 0   64  0.290  0.330  0.404  0.735    91  131   14    3   0   1    0
# 1  120  0.246  0.326  0.443  0.769    99  225   14    6   0   5    6
# 2   48  0.293  0.369  0.392  0.760   100  159   11    2   2   4    4
# 3  116  0.273  0.343  0.403  0.746    95  230   17    6   0   2    6
# 4   57  0.284  0.338  0.482  0.819   111  107    5    0   0   0    3
#
# [5 rows x 28 columns]

# %% [markdown]
# ##### tail()

# %%
# DataFrame.tail()  -- Accepts integer parameter(gives access to more rows)
bs2017.tail()
# Out:
#     Rk Pos             Name  Age   G  PA  AB  R   H  2B  3B  HR  ...  SO  \
# 18  19  IF  Marco Hernandez   24  21  60  58  7  16   3   0   0  ...  15
# 19  20  UT      Rajai Davis   36  17  38  36  7   9   2   0   0  ...  13
# 20  21  UT     Steve Selsky   27   8   9   9  0   1   1   0   0  ...   5
# 21  22  UT    Blake Swihart   25   6   7   5  1   1   0   0   0  ...   3
# 22  23  2B   Chase d'Arnaud   30   2   1   1  2   1   0   0   0  ...   0
#
#        BA    OBP    SLG    OPS  OPS+  TB  GDP  HBP  SH  SF  IBB
# 18  0.276  0.300  0.328  0.628    65  19    0    1   0   0    0
# 19  0.250  0.289  0.306  0.595    56  11    2    1   0   0    0
# 20  0.111  0.111  0.222  0.333   -16   2    0    0   0   0    0
# 21  0.200  0.429  0.200  0.629    74   1    0    0   0   0    0
# 22  1.000  1.000  1.000  2.000   428   1    0    0   0   0    0
#
# [5 rows x 28 columns]

# %% [markdown]
# ##### shape

# %%
# The dataframe has a shape property, just like a NumPy matrix. 
# print(df.shape) -- DataFrame.shape -- No Parameter

bs17.shape

# %% [markdown]
# ##### describe() <br>
# <p>Probably one of the most important methods to understand...</p>

# %%
# Collect summary statistics in one line
# DataFrame.describe() -- Accepts parameters (include, exclude)
bs2018.describe()
bs2018.describe(include='all')
# Out:
#               Rk  Pos        Name        Age           G          PA  \
# count   20.00000   20          20  20.000000   20.000000   20.000000
# unique       NaN   11          20        NaN         NaN         NaN
# top          NaN   UT  Dan Butler        NaN         NaN         NaN
# freq         NaN    4           1        NaN         NaN         NaN
# mean    10.50000  NaN         NaN  29.100000   82.350000  314.100000
# std      5.91608  NaN         NaN   4.666792   52.916294  230.972065
# min      1.00000  NaN         NaN  21.000000    2.000000    7.000000
# 25%      5.75000  NaN         NaN  25.000000   37.000000  125.500000
# 50%     10.50000  NaN         NaN  29.500000   85.500000  278.500000
# 75%     15.25000  NaN         NaN  32.500000  129.250000  510.250000
# max     20.00000  NaN         NaN  37.000000  150.000000  661.000000
#
#                 AB           R           H         2B         3B         HR  \
# count    20.000000   20.000000   20.000000  20.000000  20.000000  20.000000
# unique         NaN         NaN         NaN        NaN        NaN        NaN
# top            NaN         NaN         NaN        NaN        NaN        NaN
# freq           NaN         NaN         NaN        NaN        NaN        NaN
# mean    280.200000   43.600000   75.250000  17.650000   1.550000  10.400000
# std     203.871631   38.293053   62.462515  15.624795   1.959457  11.722224
# min       6.000000    0.000000    1.000000   0.000000   0.000000   0.000000
# 25%     115.250000   16.500000   28.000000   6.000000   0.000000   1.000000
# 50%     258.000000   29.000000   49.500000  11.000000   0.500000   6.500000
# 75%     475.500000   62.250000  115.000000  26.250000   3.000000  15.250000
# max     579.000000  129.000000  188.000000  47.000000   6.000000  43.000000
#
#         ...          SO         BA        OBP        SLG        OPS  \
# count   ...   20.000000  20.000000  20.000000  20.000000  20.000000
# unique  ...         NaN        NaN        NaN        NaN        NaN
# top     ...         NaN        NaN        NaN        NaN        NaN
# freq    ...         NaN        NaN        NaN        NaN        NaN
# mean    ...   62.150000   0.237950   0.307700   0.387500   0.695200
# std     ...   46.688526   0.061985   0.068843   0.135884   0.200419
# min     ...    1.000000   0.091000   0.143000   0.091000   0.310000
# 25%     ...   22.250000   0.218250   0.262000   0.304000   0.588000
# 50%     ...   63.000000   0.243500   0.305500   0.399000   0.712500
# 75%     ...  102.000000   0.277500   0.360500   0.441000   0.788000
# max     ...  146.000000   0.346000   0.438000   0.640000   1.078000
#
#               OPS+          TB        GDP        HBP         SH         SF  \
# count    20.000000   20.000000  20.000000  20.000000  20.000000  20.000000
# unique         NaN         NaN        NaN        NaN        NaN        NaN
# top            NaN         NaN        NaN        NaN        NaN        NaN
# freq           NaN         NaN        NaN        NaN        NaN        NaN
# mean     86.450000  127.200000   6.500000   2.750000   0.350000   2.400000
# std      52.199491  113.226183   5.633546   3.274704   0.812728   2.436564
# min     -17.000000    1.000000   0.000000   0.000000   0.000000   0.000000
# 25%      59.500000   37.500000   1.000000   0.000000   0.000000   0.000000
# 50%      91.000000   72.500000   5.500000   2.000000   0.000000   2.000000
# 75%     112.500000  192.000000   9.000000   4.250000   0.000000   4.250000
# max     186.000000  358.000000  19.000000  11.000000   3.000000   7.000000
#
#               IBB
# count   20.000000
# unique        NaN
# top           NaN
# freq          NaN
# mean     1.900000
# std      3.110255
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      2.250000
# max     11.000000
#
# [11 rows x 28 columns]

# %% [markdown]
# ##### sort_values()

# %%
# Sort based on many labels, with left-to-right priority
# sorted_data = data.sort_values('ages').reset_index()

# DataFrame.sort_values('key')

hr_sort = bs2018.sort_values('HR', ascending = False).reset_index(drop=True)
hr_sort
# Out:
#     Rk Pos                Name  Age    G   PA   AB    R    H  2B  3B  HR  ...  \
# 0    9  DH       J.D. Martinez   30  150  649  569  111  188  37   2  43  ...
# 1    8  RF        Mookie Betts   25  136  614  520  129  180  47   5  32  ...
# 2    4  SS     Xander Bogaerts   25  136  580  513   72  148  45   3  23  ...
# 3    5  3B       Rafael Devers   21  121  490  450   59  108  24   0  21  ...
# 4    6  LF   Andrew Benintendi   23  148  661  579  103  168  41   6  16  ...
# 5    2  1B      Mitch Moreland   32  124  459  404   57   99  23   4  15  ...
# 6    7  CF  Jackie Bradley Jr.   28  144  535  474   76  111  33   4  13  ...
# 7    3  2B       Eduardo Nunez   31  127  502  480   56  127  23   3  10  ...
# 8   10  MI          Brock Holt   30  109  367  321   41   89  18   2   7  ...
# 9   14  1B        Steve Pearce   35   50  165  136   19   38   8   1   7  ...
# 10  13  UT      Hanley Ramirez   34   44  195  177   25   45   7   0   6  ...
# 11   1   C          Sandy Leon   29   89  288  265   30   47  12   0   5  ...
# 12  11   C   Christian Vazquez   27   80  269  251   24   52  10   0   3  ...
# 13  12  UT       Blake Swihart   26   82  207  192   28   44  10   0   3  ...
# 14  15  2B         Ian Kinsler   36   37  143  132   17   32   6   0   1  ...
# 15  16  SS         Tzu-Wei Lin   24   37   73   65   15   16   6   1   1  ...
# 16  17  UT          Sam Travis   24   19   38   36    5    8   3   0   1  ...
# 17  18  UT    Brandon Phillips   37    9   27   23    4    3   0   0   1  ...
# 18  19  2B      Dustin Pedroia   34    3   13   11    1    1   0   0   0  ...
# 19  20   C          Dan Butler   31    2    7    6    0    1   0   0   0  ...
#
#      SO     BA    OBP    SLG    OPS  OPS+   TB  GDP  HBP  SH  SF  IBB
# 0   146  0.330  0.402  0.629  1.031   173  358   19    4   0   7   11
# 1    91  0.346  0.438  0.640  1.078   186  333    5    8   0   5    8
# 2   102  0.288  0.360  0.522  0.883   135  268   14    6   0   6    4
# 3   121  0.240  0.298  0.433  0.731    94  195    9    0   0   2    6
# 4   106  0.290  0.366  0.465  0.830   123  269    9    2   2   7    1
# 5   102  0.245  0.325  0.433  0.758   102  175   12    0   0   5    2
# 6   137  0.234  0.314  0.403  0.717    92  191    6   11   0   4    3
# 7    69  0.265  0.289  0.388  0.677    81  186   17    2   1   3    0
# 8    73  0.277  0.362  0.411  0.774   109  132    7    7   0   2    2
# 9    27  0.279  0.394  0.507  0.901   141   69    1    5   0   2    0
# 10   35  0.254  0.313  0.395  0.708    90   70    9    2   0   2    0
# 11   75  0.177  0.232  0.279  0.511    37   74    6    4   3   1    0
# 12   41  0.207  0.257  0.283  0.540    46   71    5    4   1   0    1
# 13   57  0.229  0.285  0.328  0.613    65   63    4    0   0   0    0
# 14   24  0.242  0.294  0.311  0.604    64   41    5    0   0   1    0
# 15   17  0.246  0.329  0.415  0.744   100   27    0    0   0   0    0
# 16   10  0.222  0.263  0.389  0.652    73   14    1    0   0   0    0
# 17    7  0.130  0.259  0.261  0.520    42    6    1    0   0   0    0
# 18    1  0.091  0.231  0.091  0.322    -7    1    0    0   0   0    0
# 19    2  0.167  0.143  0.167  0.310   -17    1    0    0   0   1    0
#
# [20 rows x 28 columns]

# %% [markdown]
# ##### .columns

# %%
# will show all cols headers
# DataFrame.columns -- has no parameters

print(bs2017.columns)
print(f'\n The type of bs2017.columns: {type(bs2017.columns)}')

print(bs2017.keys())
print(f'\n The type of bs2017.keys(): {type(bs2017.keys())}')
# Out:
# Index(['Rk', 'Pos', 'Name', 'Age', 'G', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR',
#        'RBI', 'SB', 'CS', 'BB', 'SO', 'BA', 'OBP', 'SLG', 'OPS', 'OPS+', 'TB',
#        'GDP', 'HBP', 'SH', 'SF', 'IBB'],
#       dtype='object')
#
#  The type of bs2017.columns: <class 'pandas.core.indexes.base.Index'>
# Index(['Rk', 'Pos', 'Name', 'Age', 'G', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR',
#        'RBI', 'SB', 'CS', 'BB', 'SO', 'BA', 'OBP', 'SLG', 'OPS', 'OPS+', 'TB',
#        'GDP', 'HBP', 'SH', 'SF', 'IBB'],
#       dtype='object')
#
#  The type of bs2017.keys(): <class 'pandas.core.indexes.base.Index'>

# %% [markdown]
# ### In-Class Exercise #2 - Describe & Sort Boston Red Sox Hitting Data <br>
# <p>Take the data that you read in earlier from the Red Sox csv's and use the describe method to understand the data better. Compare the two years and decide which team is having the better year. Then sort the values based on Batting Average.</p>

# %%
# print(bs2017.describe())
# print(bs2018.describe())

h17 = bs2017.mean().H
print(h17)

if bs2017.mean().H > bs2018.mean().H:
    answer = '2017 was a better year'
else:
    answer = '2018 was a better year'
    
print(answer)
# Out:
# 72.8
# 2018 was a better year

# %% [markdown]
# ### Filtration <br>
# <p>Let's look at how to filter dataframes for rows that fulfill a specific conditon.</p>

# %% [markdown]
# ##### Conditionals

# %%
# Conditional boolean dataframe
data['ages'] >= 25
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7     True
# 8     True
# 9     True
# Name: ages, dtype: bool

# %% [markdown]
# ##### Subsetting

# %%
# exactly like numpy
data[data['ages'] >= 25].reset_index(drop=True)
# Out:
#      names  ages
# 0    James    31
# 1    Sally    32
# 2   Lauren    33
# 3  Brandon    34
# 4  Sabrina    26

# %% [markdown]
# ### Column Transformations <br>
# <p>Rarely, if ever, will the columns in the original raw dataframe read from CSV or database table be the ones you actually need for your analysis. You will spend lots of time constantly transforming columns or groups of columns using general computational operations to produce new ones that are functions of the old ones. Pandas has full support for this: Consider the following dataframe containing membership term and renewal number for a group of customers:</p>

# %%
# Generate some fake data
customer_id = np.random.randint(1000,1100, 10)
print(customer_id)
renewal_nbr = np.random.randint(0,10,10)
print('\n',renewal_nbr)
customer_dict = {1: 0.5, 0: 1}
print('\n',customer_dict)
terms_in_years = [customer_dict[key] for key in np.random.randint(0,2,10)]
print('\n',terms_in_years)

random_data = {
    'customer_id': customer_id,
    'renewal_nbr': renewal_nbr,
    'term_in_years': terms_in_years
}

customers = pd.DataFrame.from_dict(random_data)
customers
# Out:
# [1063 1016 1036 1054 1032 1053 1003 1007 1010 1060]
#
#  [9 1 9 5 0 6 9 5 4 8]
#
#  {1: 0.5, 0: 1}
#
#  [0.5, 0.5, 1, 0.5, 0.5, 0.5, 0.5, 0.5, 1, 0.5]
#    customer_id  renewal_nbr  term_in_years
# 0         1063            9            0.5
# 1         1016            1            0.5
# 2         1036            9            1.0
# 3         1054            5            0.5
# 4         1032            0            0.5
# 5         1053            6            0.5
# 6         1003            9            0.5
# 7         1007            5            0.5
# 8         1010            4            1.0
# 9         1060            8            0.5

# %% [markdown]
# ##### Generating a New Column w/Data

# %%
# DataFrame['key'] = Some Calculation from our DataFrame Columns
customers['customer_tenure'] = customers['renewal_nbr'] * customers['term_in_years']
customers
# Out:
#    customer_id  renewal_nbr  term_in_years  customer_tenure
# 0         1063            9            0.5              4.5
# 1         1016            1            0.5              0.5
# 2         1036            9            1.0              9.0
# 3         1054            5            0.5              2.5
# 4         1032            0            0.5              0.0
# 5         1053            6            0.5              3.0
# 6         1003            9            0.5              4.5
# 7         1007            5            0.5              2.5
# 8         1010            4            1.0              4.0
# 9         1060            8            0.5              4.0

# %% [markdown]
# ##### User Defined Function
#
# <p>If what you want to do to a column that can't be represented by simple mathematical operations, you can write your own $\textit{user defined function}$ with the full customizability available in Python and any external Python packages, then map it directly onto a column. Let's add some ages to our customer dataframe, and then classify them into our custom defined grouping scheme:</p>

# %%
# use .apply to map over dataframe

# Create a new column for ages
customers['ages'] = np.random.randint(18,70,10)
customers

# user defined function to give an age group beased on the ages column

def make_groups(age):
    if age < 20:
        return 'Teenager'
    elif age < 40:
        return 'Young Adult'
    elif age < 65:
        return 'Adult'
    else:
        return 'Senior'
    
customers['age_group'] = customers['ages'].apply(make_groups)
customers
# Out:
#    customer_id  renewal_nbr  term_in_years  customer_tenure  ages    age_group
# 0         1063            9            0.5              4.5    42        Adult
# 1         1016            1            0.5              0.5    37  Young Adult
# 2         1036            9            1.0              9.0    32  Young Adult
# 3         1054            5            0.5              2.5    29  Young Adult
# 4         1032            0            0.5              0.0    31  Young Adult
# 5         1053            6            0.5              3.0    65       Senior
# 6         1003            9            0.5              4.5    49        Adult
# 7         1007            5            0.5              2.5    65       Senior
# 8         1010            4            1.0              4.0    26  Young Adult
# 9         1060            8            0.5              4.0    69       Senior

# %% [markdown]
# <p>As a last example I'll show here how you would use a lambda function to create a UDF that depends on $\textit{more than one}$ column:</p>
#
# <li>UDF = User Defined Function</li>

# %%
#Axis for apply can only be 1 or 0 -- 1 being the X axis 0 being the Y axis

def make_loyalty_age_group(row):
    age = row['ages']
    tenure = row['customer_tenure']
    
    if age < 20:
        age_group = 'Teenager'
    elif age < 40:
        age_group = 'Young Adult'
    elif age < 65:
        age_group = 'Adult'
    else:
        age_group = 'Senior'
    
    if tenure > 2:
        loyalty_age_group = f'Loyal {age_group}'
    else:
        loyalty_age_group = f'New {age_group}'
        
    return loyalty_age_group

customers['loyalty_age_group'] = customers.apply(make_loyalty_age_group, axis = 1)
customers
# Out:
#    customer_id  renewal_nbr  term_in_years  customer_tenure  ages  \
# 0         1063            9            0.5              4.5    42
# 1         1016            1            0.5              0.5    37
# 2         1036            9            1.0              9.0    32
# 3         1054            5            0.5              2.5    29
# 4         1032            0            0.5              0.0    31
# 5         1053            6            0.5              3.0    65
# 6         1003            9            0.5              4.5    49
# 7         1007            5            0.5              2.5    65
# 8         1010            4            1.0              4.0    26
# 9         1060            8            0.5              4.0    69
#
#      age_group  loyalty_age_group
# 0        Adult        Loyal Adult
# 1  Young Adult    New Young Adult
# 2  Young Adult  Loyal Young Adult
# 3  Young Adult  Loyal Young Adult
# 4  Young Adult    New Young Adult
# 5       Senior       Loyal Senior
# 6        Adult        Loyal Adult
# 7       Senior       Loyal Senior
# 8  Young Adult  Loyal Young Adult
# 9       Senior       Loyal Senior

# %% [markdown]
# ### In-Class Exercise #3 - Create Your Own UDF <br>
# <p>Using the Boston Red Sox data, create your own UDF which creates a new column called 'All-Star' and puts every player with either a batting average over .280 or an on base percentage of over .360 with a result of 'Yes' in the column and 'No' if not.</p>

# %%
"""
    Name  BA OBP AllStar
    --------------------
    Name .233 .360 Yes
    Name .150 .288 No
"""
def make_as(row):
    ba = row['BA']
    obp = row['OBP']
    ab = row['AB']
    if ab > 125 and (ba >= 0.280 or obp >= 0.360):
        all_star = 'Yes'
    else:
        all_star = 'No'
    return all_star

bs2018['AllStar'] = bs2018.apply(make_as, axis = 1)
bs2018
bs2018[['Name', 'BA', 'OBP']].loc[bs2018['AllStar'] == 'Yes']
# bs2017.drop(columns=['AllStar']) -- must save in a new variable
# Out:
#                  Name     BA    OBP
# 3     Xander Bogaerts  0.288  0.360
# 5   Andrew Benintendi  0.290  0.366
# 7        Mookie Betts  0.346  0.438
# 8       J.D. Martinez  0.330  0.402
# 9          Brock Holt  0.277  0.362
# 13       Steve Pearce  0.279  0.394

# %% [markdown]
# ### Aggregations <br>
# <p>The raw data plus some transformations is generally only half the story. Your objective is to extract actual insights and actionable conclusions from the data, and that means reducing it from potentially billions of rows to some summary statistics via aggregation functions.</p>

# %% [markdown]
# ##### groupby() <br>
# <p>The .groupby() function is in some ways a 'master' aggregation.</p>
#
# <p>Data tables will usually reserve one column as a primary key - that is, a column for which each row has a unique value. This is to facilitate access to the exact rows of a data table that a user wants to view. The other columns will often have repeated values, such as the age groups in the above examples. We can use these columns to explore the data using the Pandas API:</p>

# %%
# also introducing .count() here, exact same as to how it's used in SQL

# Using the groupby with the column intact as a column/key
# customers.groupby('age_group', as_index = False).count()[['customer_id','age_group']]

customers.groupby('age_group').count()

customers.groupby('age_group', as_index = False).count()
# Out:
#      age_group  customer_id  renewal_nbr  term_in_years  customer_tenure  \
# 0        Adult            2            2              2                2
# 1       Senior            3            3              3                3
# 2  Young Adult            5            5              5                5
#
#    ages  loyalty_age_group
# 0     2                  2
# 1     3                  3
# 2     5                  5

# %% [markdown]
# ##### Type of groupby()
#
# <p>The result is a new dataframe, the columns of which all contain the counts of the grouped field. Notice the type of a grouped dataframe:</p>

# %%
print(type(customers), 'Regular Data Frame')
print(f'\n Type of Group By for Customer.GroupBy: {type(customers.groupby("age_group"))}')
# Out:
# <class 'pandas.core.frame.DataFrame'> Regular Data Frame
#
#  Type of Group By for Customer.GroupBy: <class 'pandas.core.groupby.generic.DataFrameGroupBy'>

# %% [markdown]
# <p>This is because simply grouping data doesn't quite make sense without an aggregation function like count() to pair with. In this case, we're counting occurances of the grouped field, but that's not all we can do. We can take averages, standard deviations, mins, maxes and much more! Let's see how this works a bit more:</p>

# %% [markdown]
# ##### mean()

# %%
# mean = average
customers.groupby('age_group').mean()[['customer_tenure', 'ages']].sort_values('customer_tenure', ascending = False)
# Out:
#              customer_tenure       ages
# age_group
# Adult               4.500000  45.500000
# Young Adult         3.200000  31.000000
# Senior              3.166667  66.333333

# %% [markdown]
# ##### groupby() w/Multiple Columns
#
# <p>We end up with the average age of the groups in the last column, the average tenure in the tenure column, and so on and so forth. You can even split the groups more finely by passing a list of columns to group by:</p>

# %%
customers.groupby(['age_group', 'ages']).mean().sort_values('ages')
# Out:
#                   customer_id  renewal_nbr  term_in_years  customer_tenure
# age_group   ages
# Young Adult 26         1010.0          4.0            1.0             4.00
#             29         1054.0          5.0            0.5             2.50
#             31         1032.0          0.0            0.5             0.00
#             32         1036.0          9.0            1.0             9.00
#             37         1016.0          1.0            0.5             0.50
# Adult       42         1063.0          9.0            0.5             4.50
#             49         1003.0          9.0            0.5             4.50
# Senior      65         1030.0          5.5            0.5             2.75
#             69         1060.0          8.0            0.5             4.00

# %% [markdown]
# ##### drop_duplicates()
#
# <p>Drops all duplicates from the current dataframe</p>

# %%
customers

# %%
# Send customer data into a CSV file
customers_copy.to_csv('../files/customers.csv')

# %% [markdown]
# <p>Thus the groupby operation allows you to rapidly make summary observations about the state of your entire dataset at flexible granularity. In one line above, we actually did something very complicated - that's the power of the dataframe. In fact, the process often consists of several iterative groupby operations, each revealing greater insight than the last - if you don't know where to start with a dataset, try a bunch of groupbys!</p>

# %% [markdown]
# ### Homework Excersise #1 - Find the Total Number of Runs and RBIs for the Red Sox <br>
# <p>Get total number of home runs and rbi's</p>

# %%
# step 1: Add a new column with the key 'Team' and all column values should be 'BOS'

# step 2: Group by the 'Team' column and get total home runs and rbi's

# Produce data for both 2017 and 2018 (ie print both seperated by a newline character \n)

"""
TEAM    HR   RBI
----------------
BOS     144  538
"""
bs2017['Team'] = 'BOS17'
bs2018['Team'] = 'BOS18'

print('\n',bs2017.groupby('Team').sum()[['HR', 'RBI']])
print('\n',bs2018.groupby('Team').sum()[['HR', 'RBI']])

total = bs2017.groupby('Team').sum()[['HR', 'RBI']]
total = total.append(bs2018.groupby('Team').sum()[['HR', 'RBI']])
total

# step 1: Add a new column with the key 'Team' and all column values should be 'BOS'
# step 2: Group by the 'Team' column and get total home runs and rbi's
# Produce data for both 2017 and 2018 (ie print both separated by a newline character \n)
# Concatenate your 2 final dataframes into one dataframe outpu
# Out:
#          HR  RBI
# Team
# BOS17  168  735
#
#          HR  RBI
# Team
# BOS18  208  826
#         HR  RBI
# Team
# BOS17  168  735
# BOS18  208  826

# %% [markdown]
# ## Find the average age of runners in the 2017 Boston Marathon

# %%
marathon_data.mean().Age
# Out:
# 42.587731919727375
